# %% [markdown]
# <a href="https://colab.research.google.com/github/RKumarAccount/MyPractice/blob/main/DataType.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.version
# Out:
# '3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]'

# %%
3+5
# Out:
# 8

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
10*5
# Out:
# 50

# %%
_
# Out:
# 50

# %%
10%5
# Out:
# 0

# %%
3**2
# Out:
# 9

# %%
a=10+20j
a
# Out:
# (10+20j)

# %%
b=30+50j
a+b
# Out:
# (40+70j)

# %%
'appl'
# Out:
# 'appl'

# %%
"""app
sdsd
sksdjkdsj
sksdjkjds"""
# Out:
# 'app\nsdsd\nsksdjkdsj\nsksdjkjds'

# %%
'''bzncs
dsgsdhgjsd
sgjsfgfs'''
# Out:
# 'bzncs\ndsgsdhgjsd\nsgjsfgfs'

# %%
v=5
id(5)
# Out:
# 11645480

# %%
type(5)
# Out:
# int

# %%
len(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9147/3638286517.py in <cell line: 0>()
# ----> 1 len(v)
#
# TypeError: object of type 'int' has no len()

# %%
len(6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9147/521276918.py in <cell line: 0>()
# ----> 1 len(6)
#
# TypeError: object of type 'int' has no len()

# %%
32s='bsdgds'
32s
# Out:
#   File "/tmp/ipykernel_9147/3891567228.py", line 1
#     32s='bsdgds'
#      ^
# SyntaxError: invalid decimal literal

# %%
s43='hdkadh'
s43
# Out:
# 'hdkadh'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
5E0
# Out:
# 5.0

# %%
5e3
# Out:
# 5000.0

# %%
8e6
# Out:
# 8000000.0

# %%
-56e4
# Out:
# -560000.0

# %%
True
# Out:
# True

# %%
fale
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9147/1262933956.py in <cell line: 0>()
# ----> 1 fale
#
# NameError: name 'fale' is not defined

# %%
False+False
# Out:
# 0

# %%
t=True
f=False
print(t+f)
print(t-f)
print(t*f)
print(f/t)
# Out:
# 1
# 1
# 0
# 0.0

# %%
type(t)
# Out:
# bool

# %%
a='5.5'
a
# Out:
# '5.5'
