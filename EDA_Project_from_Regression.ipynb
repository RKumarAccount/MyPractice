# %% [markdown]
# <a href="https://colab.research.google.com/github/RKumarAccount/MyPractice/blob/main/EDA_Project_from_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
list_of_dicts = [
     {"name": "Ginger", "breed": "Dachshund", "height_cm": 22,"weight_kg": 10, "date_of_birth": "2019-03-14"},
    {"name": "Scout", "breed": "Dalmatian", "height_cm": 59,"weight_kg": 25, "date_of_birth": "2019-05-09"}
]
new_dogs = pd.DataFrame(list_of_dicts)
new_dogs
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %%
dict_of_lists = {
     "name": ["Ginger", "Scout"],
     "breed": ["Dachshund", "Dalmatian"],
     "height_cm": [22, 59],
     "weight_kg": [10, 25],
     "date_of_birth": ["2019-03-14","2019-05-09"]  }
new_dogs = pd.DataFrame(dict_of_lists)
new_dogs
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %%
# read CSV from using pandas
avocado = pd.read_csv("/content/avocado.csv")
# print the first few rows of the dataframe
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
# read CSV from using pandas and assigning Date as index of the dataframe
avocado = pd.read_csv("/content/avocado.csv",parse_dates=True, index_col='Date')
# print the first few rows of the dataframe
avocado.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# 2015-12-20  conventional  2015  Albany
# 2015-12-13  conventional  2015  Albany
# 2015-12-06  conventional  2015  Albany
# 2015-11-29  conventional  2015  Albany

# %%
avocadeo = pd.read_csv("/content/avocado.csv",parse_dates=True,index_col='Date')
avocadeo.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# 2015-12-20  conventional  2015  Albany
# 2015-12-13  conventional  2015  Albany
# 2015-12-06  conventional  2015  Albany
# 2015-11-29  conventional  2015  Albany

# %%
avocado.to_csv("/content/test_avocados.csv")

# %%
avocado.tail(10)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046     4225    4770  \
# Date
# 2018-03-11           2          1.56      22128.42  2162.67  3194.25    8.93
# 2018-03-04           3          1.54      17393.30  1832.24  1905.57    0.00
# 2018-02-25           4          1.57      18421.24  1974.26  2482.65    0.00
# 2018-02-18           5          1.56      17597.12  1892.05  1928.36    0.00
# 2018-02-11           6          1.57      15986.17  1924.28  1368.32    0.00
# 2018-02-04           7          1.63      17074.83  2046.96  1529.20    0.00
# 2018-01-28           8          1.71      13888.04  1191.70  3431.50    0.00
# 2018-01-21           9          1.87      13766.76  1191.92  2452.79  727.94
# 2018-01-14          10          1.93      16205.22  1527.63  2981.04  727.01
# 2018-01-07          11          1.62      17489.58  2894.77  2356.13  224.53
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2018-03-11    16762.57    16510.32      252.25          0.0  organic  2018
# 2018-03-04    13655.49    13401.93      253.56          0.0  organic  2018
# 2018-02-25    13964.33    13698.27      266.06          0.0  organic  2018
# 2018-02-18    13776.71    13553.53      223.18          0.0  organic  2018
# 2018-02-11    12693.57    12437.35      256.22          0.0  organic  2018
# 2018-02-04    13498.67    13066.82      431.85          0.0  organic  2018
# 2018-01-28     9264.84     8940.04      324.80          0.0  organic  2018
# 2018-01-21     9394.11     9351.80       42.31          0.0  organic  2018
# 2018-01-14    10969.54    10919.54       50.00          0.0  organic  2018
# 2018-01-07    12014.15    11988.14       26.01          0.0  organic  2018
#
#                       region
# Date
# 2018-03-11  WestTexNewMexico
# 2018-03-04  WestTexNewMexico
# 2018-02-25  WestTexNewMexico
# 2018-02-18  WestTexNewMexico
# 2018-02-11  WestTexNewMexico
# 2018-02-04  WestTexNewMexico
# 2018-01-28  WestTexNewMexico
# 2018-01-21  WestTexNewMexico
# 2018-01-14  WestTexNewMexico
# 2018-01-07  WestTexNewMexico

# %%
avocado.reset_index(drop=True)
avocado
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# 0     2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 1     2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2     2015-12-13           2          0.93     118220.22   794.70  109149.67
# 3     2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 4     2015-11-29           4          1.28      51039.60   941.48   43838.39
# ...          ...         ...           ...           ...      ...        ...
# 18244 2018-02-04           7          1.63      17074.83  2046.96    1529.20
# 18245 2018-01-28           8          1.71      13888.04  1191.70    3431.50
# 18246 2018-01-21           9          1.87      13766.76  1191.92    2452.79
# 18247 2018-01-14          10          1.93      16205.22  1527.63    2981.04
# 18248 2018-01-07          11          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   Unnamed: 0    18249 non-null  int64
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %%
avocado.shape
# Out:
# (18249, 14)

# %%
avocado.describe()
# Out:
#                                 Date    Unnamed: 0  AveragePrice  \
# count                          18249  18249.000000  18249.000000
# mean   2016-08-13 23:30:43.498273792     24.232232      1.405978
# min              2015-01-04 00:00:00      0.000000      0.440000
# 25%              2015-10-25 00:00:00     10.000000      1.100000
# 50%              2016-08-14 00:00:00     24.000000      1.370000
# 75%              2017-06-04 00:00:00     38.000000      1.660000
# max              2018-03-25 00:00:00     52.000000      3.250000
# std                              NaN     15.481045      0.402677
#
#        Total Volume          4046          4225          4770    Total Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean   8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04  2.396392e+05
# min    8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00  5.088640e+03
# 50%    1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02  3.974383e+04
# 75%    4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03  1.107834e+05
# max    6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06  1.937313e+07
# std    3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05  9.862424e+05
#
#          Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   1.821947e+05  5.433809e+04    3106.426507   2016.147899
# min    0.000000e+00  0.000000e+00       0.000000   2015.000000
# 25%    2.849420e+03  1.274700e+02       0.000000   2015.000000
# 50%    2.636282e+04  2.647710e+03       0.000000   2016.000000
# 75%    8.333767e+04  2.202925e+04     132.500000   2017.000000
# max    1.338459e+07  5.719097e+06  551693.650000   2018.000000
# std    7.461785e+05  2.439660e+05   17692.894652      0.939938

# %%
avocado.values
# Out:
# array([[Timestamp('2015-12-27 00:00:00'), 0, 1.33, ..., 'conventional',
#         2015, 'Albany'],
#        [Timestamp('2015-12-20 00:00:00'), 1, 1.35, ..., 'conventional',
#         2015, 'Albany'],
#        [Timestamp('2015-12-13 00:00:00'), 2, 0.93, ..., 'conventional',
#         2015, 'Albany'],
#        ...,
#        [Timestamp('2018-01-21 00:00:00'), 9, 1.87, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [Timestamp('2018-01-14 00:00:00'), 10, 1.93, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [Timestamp('2018-01-07 00:00:00'), 11, 1.62, ..., 'organic', 2018,
#         'WestTexNewMexico']], dtype=object)

# %%
avocado.columns
# Out:
# Index(['Date', 'Unnamed: 0', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
even = pd.Series([2,4,6,8,10])
odd = pd.Series([1,3,5,7,9])

res = pd.concat([even, odd])
res
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# dtype: int64

# %%
res=res.reset_index(drop=True)
res
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5     1
# 6     3
# 7     5
# 8     7
# 9     9
# dtype: int64

# %%
avocado=avocado.reset_index(drop=True)
#avocado
avocado.sort_values(['AveragePrice','year'],ascending=[True,False])
avocado.head(5)
# Out:
#         Date  Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# 0 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 1 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 3 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 4 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
avocado['AveragePrice'].sort_values()
# Out:
# 15261    0.44
# 7412     0.46
# 15473    0.48
# 15262    0.49
# 1716     0.49
#          ...
# 16720    3.04
# 16055    3.05
# 14124    3.12
# 17428    3.17
# 14125    3.25
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
avocado[['AveragePrice','Date']]
# Out:
#        AveragePrice       Date
# 0              1.33 2015-12-27
# 1              1.35 2015-12-20
# 2              0.93 2015-12-13
# 3              1.08 2015-12-06
# 4              1.28 2015-11-29
# ...             ...        ...
# 18244          1.63 2018-02-04
# 18245          1.71 2018-01-28
# 18246          1.87 2018-01-21
# 18247          1.93 2018-01-14
# 18248          1.62 2018-01-07
#
# [18249 rows x 2 columns]

# %%
avocado['AveragePrice']<1
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 18244    False
# 18245    False
# 18246    False
# 18247    False
# 18248    False
# Name: AveragePrice, Length: 18249, dtype: bool

# %%
avocado[avocado['AveragePrice']<1]
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# 2     2015-12-13           2          0.93     118220.22    794.70  109149.67
# 6     2015-11-15           6          0.99      83453.76   1368.92   73672.72
# 7     2015-11-08           7          0.98     109428.33    703.75  101815.36
# 13    2015-09-27          13          0.99     106803.39   1204.88   99409.21
# 43    2015-03-01          43          0.99      55595.74    629.46   45633.34
# ...          ...         ...           ...           ...       ...        ...
# 17169 2017-03-05          43          0.99     155011.12  35367.23    5175.81
# 17170 2017-02-26          44          0.99     171145.00  34520.03    6936.39
# 17536 2017-04-02          39          0.98     402676.23  34093.33   58330.53
# 17537 2017-03-26          40          0.90     456645.91  36169.35   51398.72
# 17540 2017-03-05          43          0.99     367519.17  61166.48   55123.99
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 6       93.26     8318.86     8196.81      122.05          0.0  conventional
# 7       80.00     6829.22     6266.85      562.37          0.0  conventional
# 13     154.84     6034.46     5888.87      145.59          0.0  conventional
# 43     181.49     9151.45     8986.06      165.39          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 17169    5.91   114462.17    95379.07    19083.10          0.0       organic
# 17170    0.00   129688.58   117252.31    12436.27          0.0       organic
# 17536  207.85   310044.52   155701.41   154343.11          0.0       organic
# 17537  139.55   368938.29   152159.53   216778.76          0.0       organic
# 17540  126.80   251101.90   112844.19   138257.71          0.0       organic
#
#        year        region
# 2      2015        Albany
# 6      2015        Albany
# 7      2015        Albany
# 13     2015        Albany
# 43     2015        Albany
# ...     ...           ...
# 17169  2017  SouthCentral
# 17170  2017  SouthCentral
# 17536  2017          West
# 17537  2017          West
# 17540  2017          West
#
# [2796 rows x 14 columns]

# %%
avocado[avocado['type']=='organic']
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046     4225  \
# 9126  2015-12-27           0          1.83        989.55     8.16    88.59
# 9127  2015-12-20           1          1.89       1163.03    30.24   172.14
# 9128  2015-12-13           2          1.85        995.96    10.44   178.70
# 9129  2015-12-06           3          1.84       1158.42    90.29   104.18
# 9130  2015-11-29           4          1.94        831.69     0.00    94.73
# ...          ...         ...           ...           ...      ...      ...
# 18244 2018-02-04           7          1.63      17074.83  2046.96  1529.20
# 18245 2018-01-28           8          1.71      13888.04  1191.70  3431.50
# 18246 2018-01-21           9          1.87      13766.76  1191.92  2452.79
# 18247 2018-01-14          10          1.93      16205.22  1527.63  2981.04
# 18248 2018-01-07          11          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9126     0.00      892.80      892.80        0.00          0.0  organic  2015
# 9127     0.00      960.65      960.65        0.00          0.0  organic  2015
# 9128     0.00      806.82      806.82        0.00          0.0  organic  2015
# 9129     0.00      963.95      948.52       15.43          0.0  organic  2015
# 9130     0.00      736.96      736.96        0.00          0.0  organic  2015
# ...       ...         ...         ...         ...          ...      ...   ...
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 9126             Albany
# 9127             Albany
# 9128             Albany
# 9129             Albany
# 9130             Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [9123 rows x 14 columns]

# %%
avocado[avocado['Date']<='2015-02-04']
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046      4225  \
# 47    2015-02-01          47          0.99      70873.60  1353.90  60017.20
# 48    2015-01-25          48          1.06      45147.50   941.38  33196.16
# 49    2015-01-18          49          1.17      44511.28   914.14  31540.32
# 50    2015-01-11          50          1.24      41195.08  1002.85  31640.34
# 51    2015-01-04          51          1.22      40873.28  2819.50  28287.42
# ...          ...         ...           ...           ...      ...       ...
# 11928 2015-02-01          46          1.77       7210.19  1634.42   3012.44
# 11929 2015-01-25          47          1.63       7324.06  1934.46   3032.72
# 11930 2015-01-18          48          1.71       5508.20  1793.64   2078.72
# 11931 2015-01-11          49          1.69       6861.73  1822.28   2377.54
# 11932 2015-01-04          50          1.64       6182.81  1561.30   2958.17
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 47     179.32     9323.18     9170.82      152.36          0.0  conventional
# 48     164.14    10845.82    10103.35      742.47          0.0  conventional
# 49     135.77    11921.05    11651.09      269.96          0.0  conventional
# 50     127.12     8424.77     8036.04      388.73          0.0  conventional
# 51      49.90     9716.46     9186.93      529.53          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 11928    0.00     2563.33     2563.33        0.00          0.0       organic
# 11929    0.00     2356.88     2320.00       36.88          0.0       organic
# 11930    0.00     1635.84     1620.00       15.84          0.0       organic
# 11931    0.00     2661.91     2656.66        5.25          0.0       organic
# 11932    0.00     1663.34     1663.34        0.00          0.0       organic
#
#        year            region
# 47     2015            Albany
# 48     2015            Albany
# 49     2015            Albany
# 50     2015            Albany
# 51     2015            Albany
# ...     ...               ...
# 11928  2015  WestTexNewMexico
# 11929  2015  WestTexNewMexico
# 11930  2015  WestTexNewMexico
# 11931  2015  WestTexNewMexico
# 11932  2015  WestTexNewMexico
#
# [540 rows x 14 columns]

# %%
avocado[(avocado['Date']<='2015-02-04') & (avocado['type']=='organic')]
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046     4225  \
# 9173  2015-02-01          47          1.83       1228.51    33.12    99.36
# 9174  2015-01-25          48          1.89       1115.89    14.87   148.72
# 9175  2015-01-18          49          1.93       1118.47     8.02   178.78
# 9176  2015-01-11          50          1.77       1182.56    39.00   305.12
# 9177  2015-01-04          51          1.79       1373.95    57.42   153.88
# ...          ...         ...           ...           ...      ...      ...
# 11928 2015-02-01          46          1.77       7210.19  1634.42  3012.44
# 11929 2015-01-25          47          1.63       7324.06  1934.46  3032.72
# 11930 2015-01-18          48          1.71       5508.20  1793.64  2078.72
# 11931 2015-01-11          49          1.69       6861.73  1822.28  2377.54
# 11932 2015-01-04          50          1.64       6182.81  1561.30  2958.17
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9173    0.0     1096.03     1096.03        0.00          0.0  organic  2015
# 9174    0.0      952.30      952.30        0.00          0.0  organic  2015
# 9175    0.0      931.67      931.67        0.00          0.0  organic  2015
# 9176    0.0      838.44      838.44        0.00          0.0  organic  2015
# 9177    0.0     1162.65     1162.65        0.00          0.0  organic  2015
# ...     ...         ...         ...         ...          ...      ...   ...
# 11928   0.0     2563.33     2563.33        0.00          0.0  organic  2015
# 11929   0.0     2356.88     2320.00       36.88          0.0  organic  2015
# 11930   0.0     1635.84     1620.00       15.84          0.0  organic  2015
# 11931   0.0     2661.91     2656.66        5.25          0.0  organic  2015
# 11932   0.0     1663.34     1663.34        0.00          0.0  organic  2015
#
#                  region
# 9173             Albany
# 9174             Albany
# 9175             Albany
# 9176             Albany
# 9177             Albany
# ...                 ...
# 11928  WestTexNewMexico
# 11929  WestTexNewMexico
# 11930  WestTexNewMexico
# 11931  WestTexNewMexico
# 11932  WestTexNewMexico
#
# [270 rows x 14 columns]

# %%
regionfilter=avocado['region'].isin(['Boston','Chicago'])
avocado[regionfilter]
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# 208   2015-12-27           0          1.13     450816.39  3886.27  346964.70
# 209   2015-12-20           1          1.07     489802.88  4912.37  390100.99
# 210   2015-12-13           2          1.01     549945.76  4641.02  455362.38
# 211   2015-12-06           3          1.02     488679.31  5126.32  407520.22
# 212   2015-11-29           4          1.19     350559.81  3609.25  272719.08
# ...          ...         ...           ...           ...      ...        ...
# 17704 2018-02-04           7          1.62      46956.84   313.29   32668.25
# 17705 2018-01-28           8          1.72      40770.94   215.40   31318.93
# 17706 2018-01-21           9          1.82      36688.67    83.93   28134.16
# 17707 2018-01-14          10          1.79      44955.89   133.39   31177.44
# 17708 2018-01-07          11          1.83      41573.25   118.84   29600.36
#
#            4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 208    13952.56    86012.86    85913.60       99.26          0.0
# 209     5887.72    88901.80    88768.47      133.33          0.0
# 210      219.40    89722.96    89523.38      199.58          0.0
# 211      142.99    75889.78    75666.22      223.56          0.0
# 212      105.86    74125.62    73864.52      261.10          0.0
# ...         ...         ...         ...         ...          ...
# 17704      0.00    13975.30    13975.30        0.00          0.0
# 17705      0.00     9236.61     9236.61        0.00          0.0
# 17706      0.00     8470.58     8470.58        0.00          0.0
# 17707      0.00    13645.06    13635.06       10.00          0.0
# 17708      0.00    11854.05    11850.72        3.33          0.0
#
#                type  year   region
# 208    conventional  2015   Boston
# 209    conventional  2015   Boston
# 210    conventional  2015   Boston
# 211    conventional  2015   Boston
# 212    conventional  2015   Boston
# ...             ...   ...      ...
# 17704       organic  2018  Chicago
# 17705       organic  2018  Chicago
# 17706       organic  2018  Chicago
# 17707       organic  2018  Chicago
# 17708       organic  2018  Chicago
#
# [676 rows x 14 columns]

# %%
regionfilter=avocado['region'].isin(['Boston','Chicago'])
yearfiler=avocado['year'].isin([2015,2016])
avocado[regionfilter & yearfiler]
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# 208   2015-12-27           0          1.13     450816.39  3886.27  346964.70
# 209   2015-12-20           1          1.07     489802.88  4912.37  390100.99
# 210   2015-12-13           2          1.01     549945.76  4641.02  455362.38
# 211   2015-12-06           3          1.02     488679.31  5126.32  407520.22
# 212   2015-11-29           4          1.19     350559.81  3609.25  272719.08
# ...          ...         ...           ...           ...      ...        ...
# 12396 2016-01-31          47          1.61      28813.36   814.10   27719.26
# 12397 2016-01-24          48          1.62      25004.87   976.46   23728.41
# 12398 2016-01-17          49          1.52      25573.57   777.31   24636.26
# 12399 2016-01-10          50          1.62      35835.37  1437.58   34064.46
# 12400 2016-01-03          51          1.62      24460.46   931.20   23415.93
#
#            4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 208    13952.56    86012.86    85913.60       99.26          0.0
# 209     5887.72    88901.80    88768.47      133.33          0.0
# 210      219.40    89722.96    89523.38      199.58          0.0
# 211      142.99    75889.78    75666.22      223.56          0.0
# 212      105.86    74125.62    73864.52      261.10          0.0
# ...         ...         ...         ...         ...          ...
# 12396      0.00      280.00      280.00        0.00          0.0
# 12397      0.00      300.00      300.00        0.00          0.0
# 12398      0.00      160.00      160.00        0.00          0.0
# 12399      0.00      333.33      333.33        0.00          0.0
# 12400      0.00      113.33      113.33        0.00          0.0
#
#                type  year   region
# 208    conventional  2015   Boston
# 209    conventional  2015   Boston
# 210    conventional  2015   Boston
# 211    conventional  2015   Boston
# 212    conventional  2015   Boston
# ...             ...   ...      ...
# 12396       organic  2016  Chicago
# 12397       organic  2016  Chicago
# 12398       organic  2016  Chicago
# 12399       organic  2016  Chicago
# 12400       organic  2016  Chicago
#
# [416 rows x 14 columns]

# %%
avocado.isna()
# Out:
#         Date  Unnamed: 0  AveragePrice  Total Volume   4046   4225   4770  \
# 0      False       False         False         False  False  False  False
# 1      False       False         False         False  False  False  False
# 2      False       False         False         False  False  False  False
# 3      False       False         False         False  False  False  False
# 4      False       False         False         False  False  False  False
# ...      ...         ...           ...           ...    ...    ...    ...
# 18244  False       False         False         False  False  False  False
# 18245  False       False         False         False  False  False  False
# 18246  False       False         False         False  False  False  False
# 18247  False       False         False         False  False  False  False
# 18248  False       False         False         False  False  False  False
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags   type   year  region
# 0           False       False       False        False  False  False   False
# 1           False       False       False        False  False  False   False
# 2           False       False       False        False  False  False   False
# 3           False       False       False        False  False  False   False
# 4           False       False       False        False  False  False   False
# ...           ...         ...         ...          ...    ...    ...     ...
# 18244       False       False       False        False  False  False   False
# 18245       False       False       False        False  False  False   False
# 18246       False       False       False        False  False  False   False
# 18247       False       False       False        False  False  False   False
# 18248       False       False       False        False  False  False   False
#
# [18249 rows x 14 columns]

# %%
avocado.isna().any()
# Out:
# Date            False
# Unnamed: 0      False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %%
avocado.isna().sum()
# Out:
# Date            0
# Unnamed: 0      0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avocado.dropna()
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# 0     2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 1     2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2     2015-12-13           2          0.93     118220.22   794.70  109149.67
# 3     2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 4     2015-11-29           4          1.28      51039.60   941.48   43838.39
# ...          ...         ...           ...           ...      ...        ...
# 18244 2018-02-04           7          1.63      17074.83  2046.96    1529.20
# 18245 2018-01-28           8          1.71      13888.04  1191.70    3431.50
# 18246 2018-01-21           9          1.87      13766.76  1191.92    2452.79
# 18247 2018-01-14          10          1.93      16205.22  1527.63    2981.04
# 18248 2018-01-07          11          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
meanval=avocado['AveragePrice'].mean()
avocado['AveragePrice'].fillna(meanval)
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
avocado['AveragePricePer100']=avocado['AveragePrice']*100
avocado
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# 0     2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 1     2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2     2015-12-13           2          0.93     118220.22   794.70  109149.67
# 3     2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 4     2015-11-29           4          1.28      51039.60   941.48   43838.39
# ...          ...         ...           ...           ...      ...        ...
# 18244 2018-02-04           7          1.63      17074.83  2046.96    1529.20
# 18245 2018-01-28           8          1.71      13888.04  1191.70    3431.50
# 18246 2018-01-21           9          1.87      13766.76  1191.92    2452.79
# 18247 2018-01-14          10          1.93      16205.22  1527.63    2981.04
# 18248 2018-01-07          11          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region  AveragePricePer100
# 0      2015            Albany               133.0
# 1      2015            Albany               135.0
# 2      2015            Albany                93.0
# 3      2015            Albany               108.0
# 4      2015            Albany               128.0
# ...     ...               ...                 ...
# 18244  2018  WestTexNewMexico               163.0
# 18245  2018  WestTexNewMexico               171.0
# 18246  2018  WestTexNewMexico               187.0
# 18247  2018  WestTexNewMexico               193.0
# 18248  2018  WestTexNewMexico               162.0
#
# [18249 rows x 15 columns]

# %%
avocado=avocado.drop(['AveragePricePer100'],axis=1)
avocado
# Out:
#             Date  Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# 0     2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 1     2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2     2015-12-13           2          0.93     118220.22   794.70  109149.67
# 3     2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 4     2015-11-29           4          1.28      51039.60   941.48   43838.39
# ...          ...         ...           ...           ...      ...        ...
# 18244 2018-02-04           7          1.63      17074.83  2046.96    1529.20
# 18245 2018-01-28           8          1.71      13888.04  1191.70    3431.50
# 18246 2018-01-21           9          1.87      13766.76  1191.92    2452.79
# 18247 2018-01-14          10          1.93      16205.22  1527.63    2981.04
# 18248 2018-01-07          11          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
avocado['AveragePrice'].mean()
# Out:
# np.float64(1.405978409775878)

# %%
avocado['Date'].min()
# Out:
# Timestamp('2015-01-04 00:00:00')

# %%
avocado['Date'].max()
# Out:
# Timestamp('2018-03-25 00:00:00')

# %%
def per30(column):
  return column.quantile(0.3)

def per50(column):
  return column.quantile(0.5)

avocado[['AveragePrice','Total Bags']].agg([per30,per50])
# Out:
#        AveragePrice  Total Bags
# per30          1.15    7316.634
# per50          1.37   39743.830

# %%
avocado.drop_duplicates(subset=['year'])
# Out:
#            Date  Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# 0    2015-12-27           0          1.33      64236.62   1036.74   54454.85
# 2808 2016-12-25           0          1.52      73341.73   3202.39   58280.33
# 5616 2017-12-31           0          1.47     113514.42   2622.70  101135.53
# 8478 2018-03-25           0          1.57     149396.50  16361.69  109045.03
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0      48.16     8696.87     8603.62       93.25         0.00  conventional
# 2808  426.92    11432.09    11017.32      411.83         2.94  conventional
# 5616   20.25     9735.94     5556.98     4178.96         0.00  conventional
# 8478   65.45    23924.33    19273.80     4270.53       380.00  conventional
#
#       year  region
# 0     2015  Albany
# 2808  2016  Albany
# 5616  2017  Albany
# 8478  2018  Albany

# %%
avocado['year'].value_counts(sort=True,ascending=False)
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
avocado.groupby(["year","type"])["AveragePrice"].agg([min,max,np.mean,np.median])
# Out:
# /tmp/ipykernel_5491/3594212294.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   avocado.groupby(["year","type"])["AveragePrice"].agg([min,max,np.mean,np.median])
# /tmp/ipykernel_5491/3594212294.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   avocado.groupby(["year","type"])["AveragePrice"].agg([min,max,np.mean,np.median])
# /tmp/ipykernel_5491/3594212294.py:1: FutureWarning: The provided callable <function mean at 0x79f6f4f31940> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   avocado.groupby(["year","type"])["AveragePrice"].agg([min,max,np.mean,np.median])
# /tmp/ipykernel_5491/3594212294.py:1: FutureWarning: The provided callable <function median at 0x79f6f4e81c60> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   avocado.groupby(["year","type"])["AveragePrice"].agg([min,max,np.mean,np.median])
#                     min   max      mean  median
# year type
# 2015 conventional  0.49  1.59  1.077963    1.08
#      organic       0.81  2.79  1.673324    1.67
# 2016 conventional  0.51  2.20  1.105595    1.08
#      organic       0.58  3.25  1.571684    1.53
# 2017 conventional  0.46  2.22  1.294888    1.30
#      organic       0.44  3.17  1.735521    1.72
# 2018 conventional  0.56  1.74  1.127886    1.14
#      organic       1.01  2.30  1.567176    1.55

# %%
avocado.pivot_table(index=['year','type'],aggfunc=[min,max,np.mean,np.median],values='AveragePrice')
# Out:
# /tmp/ipykernel_5491/632231490.py:1: FutureWarning: The provided callable <built-in function min> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   avocado.pivot_table(index=['year','type'],aggfunc=[min,max,np.mean,np.median],values='AveragePrice')
# /tmp/ipykernel_5491/632231490.py:1: FutureWarning: The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   avocado.pivot_table(index=['year','type'],aggfunc=[min,max,np.mean,np.median],values='AveragePrice')
# /tmp/ipykernel_5491/632231490.py:1: FutureWarning: The provided callable <function mean at 0x79f6f4f31940> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   avocado.pivot_table(index=['year','type'],aggfunc=[min,max,np.mean,np.median],values='AveragePrice')
# /tmp/ipykernel_5491/632231490.py:1: FutureWarning: The provided callable <function median at 0x79f6f4e81c60> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   avocado.pivot_table(index=['year','type'],aggfunc=[min,max,np.mean,np.median],values='AveragePrice')
#                            min          max         mean       median
#                   AveragePrice AveragePrice AveragePrice AveragePrice
# year type
# 2015 conventional         0.49         1.59     1.077963         1.08
#      organic              0.81         2.79     1.673324         1.67
# 2016 conventional         0.51         2.20     1.105595         1.08
#      organic              0.58         3.25     1.571684         1.53
# 2017 conventional         0.46         2.22     1.294888         1.30
#      organic              0.44         3.17     1.735521         1.72
# 2018 conventional         0.56         1.74     1.127886         1.14
#      organic              1.01         2.30     1.567176         1.55

# %%
avocado.set_index(['region'])
# Out:
#                        Date  Unnamed: 0  AveragePrice  Total Volume     4046  \
# region
# Albany           2015-12-27           0          1.33      64236.62  1036.74
# Albany           2015-12-20           1          1.35      54876.98   674.28
# Albany           2015-12-13           2          0.93     118220.22   794.70
# Albany           2015-12-06           3          1.08      78992.15  1132.00
# Albany           2015-11-29           4          1.28      51039.60   941.48
# ...                     ...         ...           ...           ...      ...
# WestTexNewMexico 2018-02-04           7          1.63      17074.83  2046.96
# WestTexNewMexico 2018-01-28           8          1.71      13888.04  1191.70
# WestTexNewMexico 2018-01-21           9          1.87      13766.76  1191.92
# WestTexNewMexico 2018-01-14          10          1.93      16205.22  1527.63
# WestTexNewMexico 2018-01-07          11          1.62      17489.58  2894.77
#
#                        4225    4770  Total Bags  Small Bags  Large Bags  \
# region
# Albany             54454.85   48.16     8696.87     8603.62       93.25
# Albany             44638.81   58.33     9505.56     9408.07       97.49
# Albany            109149.67  130.50     8145.35     8042.21      103.14
# Albany             71976.41   72.58     5811.16     5677.40      133.76
# Albany             43838.39   75.78     6183.95     5986.26      197.69
# ...                     ...     ...         ...         ...         ...
# WestTexNewMexico    1529.20    0.00    13498.67    13066.82      431.85
# WestTexNewMexico    3431.50    0.00     9264.84     8940.04      324.80
# WestTexNewMexico    2452.79  727.94     9394.11     9351.80       42.31
# WestTexNewMexico    2981.04  727.01    10969.54    10919.54       50.00
# WestTexNewMexico    2356.13  224.53    12014.15    11988.14       26.01
#
#                   XLarge Bags          type  year
# region
# Albany                    0.0  conventional  2015
# Albany                    0.0  conventional  2015
# Albany                    0.0  conventional  2015
# Albany                    0.0  conventional  2015
# Albany                    0.0  conventional  2015
# ...                       ...           ...   ...
# WestTexNewMexico          0.0       organic  2018
# WestTexNewMexico          0.0       organic  2018
# WestTexNewMexico          0.0       organic  2018
# WestTexNewMexico          0.0       organic  2018
# WestTexNewMexico          0.0       organic  2018
#
# [18249 rows x 13 columns]

# %%
avacado[avocado['region'].isin(['Albany','WestTexNewMexico'])]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [673 rows x 13 columns]

# %%
avocado['AveragePrice'].hist(bins=20)
plt.show()

# %%
avocado['AveragePrice'].hist()
plt.show()

# %%
regionfilter=avocado.groupby('region')['AveragePrice'].mean().head(10)
regionfilter
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# BuffaloRochester       1.516834
# California             1.395325
# Charlotte              1.606036
# Chicago                1.556775
# CincinnatiDayton       1.209201
# Name: AveragePrice, dtype: float64

# %%
regionfilter.plot(kind='bar',rot=45,title='Average Price')
plt.show()

# %%
avocado.plot(x='AveragePrice',y='Total Volume',kind='scatter')
# Out:
# <Axes: xlabel='AveragePrice', ylabel='Total Volume'>
