# %% [markdown]
# <a href="https://colab.research.google.com/github/RKumarAccount/MyPractice/blob/main/Numpy_practicle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # array

# %%
import matplotlib.pyplot as plt #visualization

# %%
from PIL import Image # python image library

# %%
feature_image = Image.open(r'C:\Users\Admin\Desktop\pic.jpg')

# %%
feature_image

# %%
#myimage = Image.open(r'C:\Users\Admin\Desktop\img.jpg')

# %%
#myimage

# %%
print(type(feature_image))
print(type(myimage))

# %%
fea_arr = np.asarray(feature_image)
fea_arr

# %%
plt.imshow(fea_arr)
plt.show()

# %%
fea_arr.shape

# %%
my_arr = np.asarray(myimage)
my_arr

# %%
plt.imshow(my_arr)
plt.show()

# %%
my_arr.shape
