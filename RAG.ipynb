# %% [markdown]
# <a href="https://colab.research.google.com/github/RKumarAccount/MyPractice/blob/main/RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pypdf -q
# !pip install langchain -q
# !pip install faiss-cpu -q
# !pip install sentence-transformers -q
# !pip install google-generativeai -q
# !pip install langchain-community -q

# %%
# !pip install langchain-text-splitters -q

# %%
from pypdf import PdfReader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
import google.generativeai as genai

# %%
pdf = PdfReader("/content/01 ML Intro.pdf")

text = ""

# %%
for page in pdf.pages:
    text += page.extract_text()

print("PDF Loaded Successfully")
# Out:
# PDF Loaded Successfully

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = splitter.split_text(text)

print("Total Chunks:", len(chunks))
# Out:
# Total Chunks: 31

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Store embeddings in FAISS
vector_db = FAISS.from_texts(chunks, embedding_model)

print("Vector Database Created")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Vector Database Created

# %%
genai.configure(api_key="AIzaSyCAW4XWFhEiA7jlXyHVUzTElDJeL3G8xfo")

model = genai.GenerativeModel("gemini-2.5-flash")

# %%
question = input("Ask Question: ")
# Out:
# Ask Question: Exception Handling

# %%
docs = vector_db.similarity_search(question, k=3)

context = ""

for doc in docs:
    context += doc.page_content + "\n"

    print(doc.page_content)
# Out:
# 8.  Exception Handling Architecture
#       Key Components
# 1️. Try Block – Contains code that may raise an error.
# 2️. Except / Catch Block – Handles the error.
# 3️. Finally Block – Executes regardless of an error occurring.
# 4️. Raise / Throw – Explicitly raises an exception.
#
# 9️. Interview Questions & Answers on Exception Handling
#     Basic Level (For Beginners)
# 1. What is an Exception?
# Ans:
# ✔Use specific exceptions instead of generic Exception.
# ✔Log exceptions for debugging.
# ✔Avoid suppressing exceptions without handling them.
# ✔Use finally to clean up resources like files and database connections.
#
#      Conclusion: When to Use Exception Handling?
#  Naresh i T echnologies        |      info@nareshit.com        |      website: www.nareshit.com
# ✔Always handle errors that can be predicted (e.g., invalid input).
# Ans: In Python, multiple exceptions can be handled like this:
# python
# CopyEdit
# try:
#     result = 10 / int(input("Enter a number: "))
# ...

# %%
prompt = f"""
Answer the question using below context only.

Context:
{context}

Question:
{question}
"""

response = model.generate_content(prompt)

print("\nANSWER:\n")
print(response.text)
# Out:
# ANSWER:
#
# Exception Handling is an architecture designed to manage errors that may occur during program execution. It should always be used to handle predictable errors, such as invalid input.
#
# **Key Components:**
# *   **Try Block:** Contains code that may raise an error.
# *   **Except / Catch Block:** Handles the error.
# *   **Finally Block:** Executes regardless of an error occurring.
# *   **Raise / Throw:** Explicitly raises an exception.
#
# **Best Practices:**
# *   Use specific exceptions instead of generic Exception.
# *   Log exceptions for debugging.
# *   Avoid suppressing exceptions without handling them.
# *   Use `finally` to clean up resources like files and database connections.
#
# **Performance Impact:**
# *   Exception handling introduces overhead in execution.
# *   Using excessive try-catch blocks slows performance.
# *   Silent failures can make debugging harder.
#
# **Handling Multiple Exceptions (Example):**
# ...
