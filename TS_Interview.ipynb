# %% [markdown]
# <a href="https://colab.research.google.com/github/RKumarAccount/MyPractice/blob/main/TS_Interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l1=[1,2,2]
l3=[2,3.4]

l=l1+l3

# %%
l
# Out:
# [1, 2, 2, 2, 3.4]

# %%
for i in l3:
  l1.append(i)

print(l1)
# Out:
# [1, 2, 2, 2, 3.4]

# %%
l1.extend(l3)

# %%
l1
# Out:
# [1, 2, 2, 2, 3.4, 2, 3.4]

# %%
l
# Out:
# [1, 2, 2, 2, 3.4]

# %%
l1
# Out:
# [1, 2, 2, 2, 3.4, 2, 3.4]

# %%
l2=[3,4,5]
l1=[2,3]

# %%
result=[x for x in l2]+[x for x in l1]

# %%
result
# Out:
# [3, 4, 5, 2, 3]

# %%
res=[*l1,*l2]

# %%
res
# Out:
# [2, 3, 3, 4, 5]

# %%
t=(1,2,3,4)

# %%
t[0]
# Out:
# 1

# %%
t[0]=11
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5366/3484712713.py in <cell line: 0>()
# ----> 1 t[0]=11
#
# TypeError: 'tuple' object does not support item assignment

# %%
def nae():
  return(102,'rk')

x, y= nae()

# %%
print(x,y)
# Out:
# 102 rk

# %%
#iteratable

def sq(lst):

  for i in lst:
    yield i*i

gen=sq([1,2,3,4])

print(next(gen))
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 4
# 9
# 16

# %%
#generator expression

gen=(x for x in range(5))

for i in gen:
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
name=['ran','kum']
age=[43,23]

res=zip(name, age)

list(res)
# Out:
# [('ran', 43), ('kum', 23)]

# %%
for n , a in zip(name, age):
  print(n,a)
# Out:
# ran 43
# kum 23

# %%
d=dict(zip(name, age))
print(d)
# Out:
# {'ran': 43, 'kum': 23}

# %%
import copy

old=[[1,2],[3,4]]

new=copy.copy(old)

print(old)
new[0][0] = 100

print(old)
# Out:
# [[1, 2], [3, 4]]
# [[100, 2], [3, 4]]

# %%
print(id(old))
print(id(new))
# Out:
# 134800179451520
# 134800179449152

# %%
old1=[[1,2],[3,4]]

new1=copy.deepcopy(old1)
print(id(old1))
print(id(new1))
new1[0][0] = 100

print(old1)
# Out:
# 134800179748928
# 134800179457856
# [[1, 2], [3, 4]]

# %%
a=[1]*5
a
# Out:
# [1, 1, 1, 1, 1]

# %%
def test(*arg):
  print(arg)
  print(type(arg))

test(1,2,3,4)
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
l=[1,2,3,4]
test(*l)
#
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
try:
    x = int("abc")

except ValueError:
    print("Invalid conversion")

except Exception as e:
    print(e)
# Out:
# Invalid conversion

# %%
try:
    file = open("a.txt")

except FileNotFoundError:
    print("File missing")

finally:
    print("Cleanup code")

# %%
class A:
    def show(self):
        print("A")

class B(A):
    pass

class C(A):
    def show(self):
        print("C")

class D(B, C):
    pass

obj = D()
obj.show()
# Out:
# C

# %%
import mysql.connector

# The connection to 'localhost' will not work in Google Colab
# as it tries to access a MySQL server on your local machine.
# To connect to a database from Colab, you typically need:
# 1. A cloud-hosted MySQL instance (e.g., Google Cloud SQL, AWS RDS).
# 2. Appropriate credentials and network configuration (e.g., public IP, authorized networks).

# Example of how you would connect if you had a remote database:
# conn = mysql.connector.connect(
#     host="your_remote_db_host",
#     user="your_db_user",
#     password="your_db_password",
#     database="your_database_name"
# )

# This code will currently not run due to the connection issue.
# Uncomment and modify with your actual remote database details if you have one.
# cursor = conn.cursor()
# query = "SELECT * FROM student"
# cursor.execute(query)

# for row in cursor.fetchall():
#     print(row)

# conn.close()
